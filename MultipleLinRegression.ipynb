# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from pylab import rcParams

import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale


# import the the counter class from collections module which will be used to count the number of times a value occurs in a list
from collections import Counter

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10,12

# %%
ads = pd.read_csv('enrollment_forecast.csv')

enroll = pd.read_csv('enrollment_forecast.csv')
enroll.columns = ['year','roll','unem','hgrad','inc']

enroll.head()
# Out:
#    year  roll  unem  hgrad   inc
# 0     1  5501   8.1   9552  1923
# 1     2  5945   7.0   9680  1961
# 2     3  6629   7.3   9731  1979
# 3     4  7556   7.5  11666  2030
# 4     5  8716   7.0  14675  2112

# %%
sns.pairplot(enroll)

# %%
## Check the correlation between the variables
print(enroll.corr())
# Out:
#            year      roll      unem     hgrad       inc
# year   1.000000  0.900934  0.378305  0.670300  0.944287
# roll   0.900934  1.000000  0.391344  0.890294  0.949876
# unem   0.378305  0.391344  1.000000  0.177376  0.282310
# hgrad  0.670300  0.890294  0.177376  1.000000  0.820089
# inc    0.944287  0.949876  0.282310  0.820089  1.000000

# %%
enrol_date = enroll[['unem','hgrad']].values

enroll_target = enroll['roll'].values
enroll_data_names = ['unem','hgrad']

X,y = scale(enrol_date), enroll_target

# %%
missing_value = X == np.nan
X[missing_value == True]
# Out:
# array([], dtype=float64)

# %%
Lin_reg = LinearRegression()

Lin_reg.fit(X,y)
print(Lin_reg.score(X,y))
# Out:
# 0.8488812666133723
